# %% [markdown]
# # MIDTERM

# %% [markdown]
# ### Python

# %% [markdown]
# 1. (1pt) What is Python?

# %%
# Python is an open-source programming language used by millions of people across the globe. 
# Like all programming languages, Python has a unique syntax to write commands, as well as a range of functions and tools that can be used to achieeve user goals.
# Python is unique in that it is open source and contributed to by many users in order to continually add new functionality.

# %% [markdown]
# 2. (1pt) How do you convert a string to all lowercase? Give an example.

# %%
# By using the lower() function 

x = "HELLO"
print(x.lower())
# Out:
# hello

# %% [markdown]
# 3. (1pt)How do you convert a string to a list in python? Give an example.

# %%
# There are multiple ways.  One way is by using the list() function

x = list('jackson')
print(x)
# Out:
# ['j', 'a', 'c', 'k', 's', 'o', 'n']

# %% [markdown]
# 4. (1pt) How do you convert a string to a tuple with each letter as an element in python? Give an example.

# %%
# We can use the tuple() function as follows:

tup1 = tuple("Library")

print(tup1)
# Out:
# ('L', 'i', 'b', 'r', 'a', 'r', 'y')

# %% [markdown]
# 5. (1pt) How do you convert a string to a set of unique letters in python? Give an example.

# %%
# One way of doing it is using the set() function on a string variable, as below:

str_animal = "cat"
set_animal = set(a)

print(set_animal)

# %% [markdown]
# 6. (1pt) How will you convert a string to an float in python? Give an example.

# %%
# One way is by using the float() function.  See the example below.

x = "12.3"
print(float(x))

# %% [markdown]
# 7. (1pt) What are Python's dictionaries? Why are they useful?

# %%
# Dictionaries are a data type in Python 
# Unlike other data types like lists, dictionaries are unique in that they consist of a key-value pair.
# Dictionaries are unordered and are mutable. 
# Values can be called by referencing the corresponding value (as opposed to through incides as in lists)
# Dictionaries are efficient because specific values can be found very quickly and easily with the corresponding key as opposed to needing to loop through each and every item in a list.

# %% [markdown]
# 8. (1pt) Create a dictionary with keys and values. Give an example.

# %%
countries = ["US", "Kenya", "Argentina"]
capitals = ["DC", "Nairobi", "Buenos Aires"]
country_capitals = dict(zip(countries, capitals))

print(country_capitals)

# %% [markdown]
# 9. (1pt) How do you get all the values from the dictionary? Give an example.

# %%
# We can get all the values from the dictionary by using the .values() function.  See example below:

print(country_capitals.values())

# %% [markdown]
# 10. (1pt) How do you get all the keys from the dictionary? Give an example.

# %%
# We can get all the keys from the dictionary by using the .keys() function.  See example below:

print(country_capitals.keys())

# %% [markdown]
# 11. (1pt) How do you capitalizes first letter of string? Give an example.

# %%
# We can capiatlize the first letter of a string with the .capitalize() function

x = "jackson"
print(x.capitalize())

# %% [markdown]
# 12. (1pt) How do you check in a string that all characters are digits? Give an example.

# %%
# We can use the isdecimal() function.  See the two examples below:

x = "abc"
print(x.isdigit())

y = "123"
print(y.isdigit())

# %% [markdown]
# 13. (1pt) How do you check in a string that all characters are alphanumeric? Give an example.

# %%
# We can use the isalpha() function.  See the two examples below:

x = "abc"
print(x.isalnum())

y = "123"
print(y.isalnum())

z = "** //"
print(z.isalnum())

# %% [markdown]
# 14. (1pt) How do you check in a string that all characters are in lowercase? Give an example.

# %%
# We can use the islower() function.  See the two examples below:

x = "CONNECTICUT"
print(x.islower())

y = "yale"
print(y.islower())

# %% [markdown]
# 15. (1pt) How do you check in a string that all characters are not numbers. Give an example.

# %%
# We can use the isalpha() function.

x = "CONNECTICUT"
y = "123"
z = "a123b"

print(x.isalpha())
print(y.isalpha())
print(z.isalpha())

# %% [markdown]
# 16. (1pt) How do you get the length of the string? Give an example.

# %%
# We can get the length of a string with the length function len()

a = "University"
print(len(a))

# %% [markdown]
# 17. (1pt) How do you convert a string to all lowercase? Give an example.

# %%
# We can convert a string to all lower case with the .lower() function

m = "MARX LIBRARY"
print(m.lower())

# %% [markdown]
# 18. (1pt) How do you remove all leading whitespace in string? Give an example.

# %%
# We can use the strip() function

str1 = "    hi"
str2 = str1.strip()

print(str2)

# %% [markdown]
# 19. (1pt) What is the difference between del() and remove() methods of list? Give an example.

# %%
# del is known as a Python statement, whereas remove() is a function.

NBA_players = ["Lebron", "Giannis", "Kevin Durant", "James Harden"]
del NBA_players[2]
print(NBA_players)

S_America = ["Brazil", "Chile", "Paraguay", "Uruguay", "Argentina"]
S_America.remove("Brazil")
print(S_America)

# %% [markdown]
# 20. (1pt) How do you get the index of an object in a list? Give an example.

# %%
# We can use the index() function, followed by the name of the object whose index we hope to find.

S_America = ["Brazil", "Chile", "Paraguay", "Uruguay", "Argentina"]
S_America.index("Chile")

# %% [markdown]
# 21. (1pt) How do you insert an object at given index in a list? Give an example.

# %%
# We can use the .insert(index, object) function.  

NBA_players = ["Lebron", "Giannis", "Kevin Durant", "James Harden"]
NBA_players.insert(3, "Steph Curry")

print(NBA_players)

# %% [markdown]
# 22. (1pt) How do you get the length of a list? Give an example.

# %%
# we can use the len() function

Apples = ["Granny Smith", "Fuji", "Pinky Lady", "Honeycrisp"]
print(len(Apples))

# %% [markdown]
# 23. (1pt) How do you remove last object from a list?

# %%
# One way of removing the last object from a list is the pop() function.  

Apples = ["Granny Smith", "Fuji", "Pinky Lady", "Honeycrisp"]
Apples.pop()
print(Apples)

# %% [markdown]
# 24. (1pt) How do you reverse a list? Give an example.

# %%
# Variable name, followed by index[::-1].  See below:

Apples = ["Granny Smith", "Fuji", "Pinky Lady", "Honeycrisp"]
print(Apples[::-1])

# %% [markdown]
# 25. (1pt) How would you slice a list? Give an example.

# %%
# Generally speaking,  we use the index function with two positions separated by a colon
# What we enter into the index first will specify where we want to start 
# What we put after the colon will go to that position -1
# If we want to go to the very last item in a list, we put the starting position followed by a colon, e.g.: variable[2:]

GLBL550 = ["Elen", "Doug", "Chandra", "Hayoung", "Bourne", "Sylvie", "Ali"]
print(GLBL550[2:5])
print(GLBL550[2:])

# %% [markdown]
# 26. (10 pts) Iterate through a list and create a new list with only happy words. A happy is anything above the threshold. Print your happy word list without values (just words).

# %%
threshold = 0.5
feelings = [('blue', 0.1), ('melancholy',0.4), ('fine', 0.5 ), ('okay',0.5), ('overjoyed',1.0), ('blissful',0.9), ('chocolately',0.8)]
# Your answer here:
good_vibes =[]

for i, tuple in enumerate(feelings):
    element_one = tuple[0]
    element_two = tuple[1]
    if element_two > threshold: 
        good_vibes.append(element_one)
        
print(good_vibes)
# Out:
# ['overjoyed', 'blissful', 'chocolately']

# %% [markdown]
# 27. (5 pts) Take a user input that takes in a user's name, age.
# Create an f string that prints "Hello (name), how does it feel to be (age)?"
# Then create an answer that takes a random choice from your happy_word list, and print "Gee, it feels (happy_word) to be (age). Thanks for asking!"

# %%
import random
name = input("What is your name? : ")
age = int(input("What is your age? : "))
happy_word = ["great", "fantastic", "wonderful", "awesome"]

print(f'Hello {name}, how does it feel to be {age}?')

print(f'Gee, it feels {random.choice(happy_word)} to be {age}')
# Out:
# What is your name? : Zubin
# What is your age? : 31
# Hello Zubin, how does it feel to be 31?
# Gee, it feels wonderful to be 31

# %% [markdown]
# 28. (15 pts) Write a for-loop to calculate pi using the Leibniz Formula (https://www.wikiwand.com/en/Leibniz_formula_for_%CF%80). The pseudo-code is as follows:
#
#  1. Initialize k=1
#  2. Initialize s=0
#  3. Run a for-loop from 0 to 10000 (for i in range(10000):)
#  4. Inside the for-loop: if i is even do s = s + 4/k, else (if i is odd) do s = s - 4/k
#  5. After the if-else, increment k by 2, continue the for-loop
#  6. print(s) at the end after the for-loop is done executing

# %%
k = 1
s = 0

for i in range(10000):
    if i % 2 == 0:
        s = s + 4/k
    else: 
        s = s - 4/k
    k = k +2 

print(s)
# Out:
# 3.1414926535900345

# %% [markdown]
# 29. (5 pts) Rewrite the previous solution as a function, instead of running it for 10,000 iterations, take in the number of iterations to run as an argument (or parameter) for the function. Try running the function with 100,000 iterations. Don't forget doc string!

# %%
def pifunc(iterations):
    '''function to take in # of iterations and then run Leibniz Formula that many times'''
    k = 1
    s = 0
    for i in range(iterations):
        if i % 2 == 0:
            s = s + 4/k
        else: 
            s = s - 4/k
        k = k +2 
        print(s)
        
pifunc(100000)
# Out:
# 4.0
# 2.666666666666667
# 3.466666666666667
# 2.8952380952380956
# 3.3396825396825403
# 2.9760461760461765
# 3.2837384837384844
# 3.017071817071818
# 3.2523659347188767
# 3.0418396189294032
# 3.232315809405594
# 3.058402765927333
# 3.2184027659273333
# 3.0702546177791854
# 3.208185652261944
# 3.079153394197428
# 3.200365515409549
# 3.0860798011238346
# 3.1941879092319425
# 3.09162380666784
# 3.189184782277596
# 3.0961615264636424
# 3.1850504153525314
# 3.099944032373808
# 3.1815766854350325
# 3.1031453128860127
# 3.1786170109992202
# 3.1058897382719475
# 3.1760651768684385
# 3.108268566698947
# 3.1738423371907505
# 3.110350273698687
# 3.1718887352371485
# 3.112187242699835
# 3.1701582571925884
# 3.1138202290235744
# 3.1686147495715193
# 3.115281416238186
# 3.167229468186238
# 3.116596556793833
# 3.1659792728432157
# 3.117786501758878
# 3.1648453252882898
# 3.118868313794037
# 3.163812134018756
# 3.1198560900627124
# 3.1628668427508844
# 3.1207615795929895
# 3.161998692995051
# ...

# %% [markdown]
# 30. (10 pts) Convert the following quote to a single string assigned to the variable Brzezinski, without numbers or special characters. Print the output. Make sure you add quotation marks to the beginning and end of the quote.

# %%
quote = [[('Most Americans ^331 are close to total ignorance about the world. They are ignorant. That is an unhealthy condition in a country in which foreign policy has to be endorsed by the people 402 if it is to be pursued. And 404 it makes it much more difficult for any president to pursue an intelligent %%&* policy that does justice to the complexity of the world.')]]
str1 = str(quote)
symbols = "]%^[_+&*!@#$"

for i in symbols:
    str1 = str1.replace(i,"")

Brzezinski = ''.join([i for i in str1 if not i.isdigit()])

print(Brzezinski)
# Out:
# 'Most Americans  are close to total ignorance about the world. They are ignorant. That is an unhealthy condition in a country in which foreign policy has to be endorsed by the people  if it is to be pursued. And  it makes it much more difficult for any president to pursue an intelligent  policy that does justice to the complexity of the world.'

# %% [markdown]
# ### Github

# %% [markdown]
# 31. (1pt) How do I initially clone a Github repository on the Github website to my local computer? Give an example of the command that you would use in the terminal.

# %%
# We can use the git clone command.  
# Example from earlier in the semester: git clone https://github.com/Jackson-Institute/assignment-upstream-fall-2021.git

# %% [markdown]
# 32. (1pt) How do I check whether if I am connected to the right repository on the remote (hint hint) Github website in the terminal?

# %%
# We can use git remote -v
# If we are, it will show us origin, followed by a github link, followed by (fetch)
# and, origin, followed by a github link, followed by (push)

# %% [markdown]
# 33. (1pt) Explain what "origin main" means.

# %%
# Origin main represents the master branch of our local repository. 
# We pull items from our remote Github repository to our local repository through git pull origin main
# We push items from our local repository to Github with git push origin main.

# %% [markdown]
# ### Final Project

# %% [markdown]
# 34. (3pts) Find a partner/group to work on your final project with! List the name of the person/people who you'd want to work with here:

# %%
# Have spoken to Bourne and Hayoung about working together as of now.  Will be speaking to a few others as well!
